# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 231.911
# The Mean absolute error is 12.428

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 這組資料想解決的問題如何評估
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

# %% [markdown]
# ## 作業二
# https://www.kaggle.com/dgawlik/nyse
# New York Stock Exchange
# 1. 他有著 S&P 500 2010-2016 的歷史股價、憑證等等相關資料，在股市上是很重要的歷史資料
# 2. 從 Yahoo Finance 取得，是基於 Nasdaq，延伸來自於 SEC 的資料庫
# 3. Price.csv, price-split-adjusted.csv(price after adjustment), securities.csv, fundemental.csv(from SEC 10K fillings)
# 4. 想得知 2017 平均 YTM 區間為何，運用資料統計之後再去翻 2017 的價格去回推 YTM 得知是否在這個區間之中
#
# ## 作業三
# 1. 核心問題為車子可能會有空閒、無載客的時間，要盡量減少這些時間，這樣就間接的提升業績。因此我的假設是把司機開車的時間分成三段：無載客時間、準備載客但還未接到人、載客時間，而司機是採像是 UBER 一樣的方式。
# 2. 資料來自 APP 中，能得知到每一個人上車、下車點，哪個區域與哪個時段的需求量最高，並且通過供需自動調整物價。因此能取得的原始資料有：每個會員在哪個時間點在哪裡上車。而這些資料需要在經過清理。
# 3. 蒐集來的資料以統計數字為主，如：台北市在 19:00-21:00 的載客人數有多少。
# 4. 我要回答的問題是如何減少空閒時間，並且透過利潤最大化取得最適的載客時間。給予模型一個評分機制，並且透過 penalty 來確認這個模型。
